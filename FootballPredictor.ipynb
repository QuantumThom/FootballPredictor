# %%
# DATA IMPORTEREN

import pandas as pd

data = pd.read_csv("data/2023_2024.csv")

# %%
list(data.columns)
# Out:
# ['Div',
#  'Date',
#  'Time',
#  'HomeTeam',
#  'AwayTeam',
#  'FTHG',
#  'FTAG',
#  'FTR',
#  'HTHG',
#  'HTAG',
#  'HTR',
#  'HS',
#  'AS',
#  'HST',
#  'AST',
#  'HF',
#  'AF',
#  'HC',
#  'AC',
#  'HY',
#  'AY',
#  'HR',
#  'AR',
#  'B365H',
#  'B365D',
#  'B365A',
#  'BWH',
#  'BWD',
#  'BWA',
#  'IWH',
#  'IWD',
#  'IWA',
#  'PSH',
#  'PSD',
#  'PSA',
#  'WHH',
#  'WHD',
#  'WHA',
#  'VCH',
#  'VCD',
#  'VCA',
#  'MaxH',
#  'MaxD',
#  'MaxA',
#  'AvgH',
#  'AvgD',
#  'AvgA',
#  'B365>2.5',
#  'B365<2.5',
#  'P>2.5',
#  'P<2.5',
#  'Max>2.5',
#  'Max<2.5',
#  'Avg>2.5',
#  'Avg<2.5',
#  'AHh',
#  'B365AHH',
#  'B365AHA',
#  'PAHH',
#  'PAHA',
#  'MaxAHH',
#  'MaxAHA',
#  'AvgAHH',
#  'AvgAHA',
#  'B365CH',
#  'B365CD',
#  'B365CA',
#  'BWCH',
#  'BWCD',
#  'BWCA',
#  'IWCH',
#  'IWCD',
#  'IWCA',
#  'PSCH',
#  'PSCD',
#  'PSCA',
#  'WHCH',
#  'WHCD',
#  'WHCA',
#  'VCCH',
#  'VCCD',
#  'VCCA',
#  'MaxCH',
#  'MaxCD',
#  'MaxCA',
#  'AvgCH',
#  'AvgCD',
#  'AvgCA',
# ...

# %%
# FILTER COLUMNS

columns_needed = ["Date", "Time", "HomeTeam", "AwayTeam", "FTHG", "FTAG", "FTR", "HTHG", "HTAG", "HTR"]
data = data[columns_needed]
data.head()
# Out:
#          Date   Time       HomeTeam          AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  11/08/2023  19:00       Volendam           Vitesse     1     2   A     1
# 1  12/08/2023  15:30  PSV Eindhoven           Utrecht     2     0   H     1
# 2  12/08/2023  17:45     Heerenveen          Waalwijk     3     1   H     3
# 3  12/08/2023  19:00           Ajax          Heracles     4     1   H     1
# 4  12/08/2023  20:00         Zwolle  Sparta Rotterdam     1     2   A     0
#
#    HTAG HTR
# 0     0   H
# 1     0   H
# 2     0   H
# 3     1   D
# 4     1   A

# %%
data["HomeTeam"].unique()
# Out:
# array(['Volendam', 'PSV Eindhoven', 'Heerenveen', 'Ajax', 'Zwolle',
#        'Nijmegen', 'AZ Alkmaar', 'Feyenoord', 'Almere City', 'Heracles',
#        'Excelsior', 'Vitesse', 'For Sittard', 'Go Ahead Eagles',
#        'Utrecht', 'Sparta Rotterdam', 'Twente', 'Waalwijk'], dtype=object)
